# %%
#importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
df =pd.read_csv(r"C:\Users\anike\Downloads\wheat (1).csv")

# %%
# read the data
df
# Out:
#       area  perimeter  compactness  length  width  asymmetry coefficient  \
# 0    15.26      14.84       0.8710   5.763  3.312                  2.221
# 1    14.88      14.57       0.8811   5.554  3.333                  1.018
# 2    14.29      14.09       0.9050   5.291  3.337                  2.699
# 3    13.84      13.94       0.8955   5.324  3.379                  2.259
# 4    16.14      14.99       0.9034   5.658  3.562                  1.355
# ..     ...        ...          ...     ...    ...                    ...
# 205  12.19      13.20       0.8783   5.137  2.981                  3.631
# 206  11.23      12.88       0.8511   5.140  2.795                  4.325
# 207  13.20      13.66       0.8883   5.236  3.232                  8.315
# 208  11.84      13.21       0.8521   5.175  2.836                  3.598
# 209  12.30      13.34       0.8684   5.243  2.974                  5.637
#
#      groove length  category
# 0            5.220       1.0
# 1            4.956       1.0
# ...

# %% [markdown]
# # Info about data

# %%
# to check no of rows and col
df.shape
# Out:
# (210, 8)

# %%
df.describe()
# Out:
#              area   perimeter  compactness      length       width  \
# count  210.000000  210.000000   210.000000  210.000000  210.000000
# mean    14.847524   14.559286     0.870999    5.628533    3.258605
# std      2.909699    1.305959     0.023629    0.443063    0.377714
# min     10.590000   12.410000     0.808100    4.899000    2.630000
# 25%     12.270000   13.450000     0.856900    5.262250    2.944000
# 50%     14.355000   14.320000     0.873450    5.523500    3.237000
# 75%     17.305000   15.715000     0.887775    5.979750    3.561750
# max     21.180000   17.250000     0.918300    6.675000    4.033000
#
#        asymmetry coefficient  groove length    category
# count             210.000000     210.000000  210.000000
# mean                3.700201       5.408071    2.000000
# std                 1.503557       0.491480    0.818448
# min                 0.765100       4.519000    1.000000
# 25%                 2.561500       5.045000    1.000000
# ...

# %%
# to check the dtype, column name , not null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   area                   210 non-null    float64
#  1   perimeter              210 non-null    float64
#  2   compactness            210 non-null    float64
#  3   length                 210 non-null    float64
#  4   width                  210 non-null    float64
#  5   asymmetry coefficient  210 non-null    float64
#  6   groove length          210 non-null    float64
#  7   category               210 non-null    float64
# dtypes: float64(8)
# memory usage: 13.3 KB

# %%
# top 5 rows of dataset
df.head()
# Out:
#     area  perimeter  compactness  length  width  asymmetry coefficient  \
# 0  15.26      14.84       0.8710   5.763  3.312                  2.221
# 1  14.88      14.57       0.8811   5.554  3.333                  1.018
# 2  14.29      14.09       0.9050   5.291  3.337                  2.699
# 3  13.84      13.94       0.8955   5.324  3.379                  2.259
# 4  16.14      14.99       0.9034   5.658  3.562                  1.355
#
#    groove length  category
# 0          5.220       1.0
# 1          4.956       1.0
# 2          4.825       1.0
# 3          4.805       1.0
# 4          5.175       1.0

# %%
# bottom 5 rows of dataset
df.tail()
# Out:
#       area  perimeter  compactness  length  width  asymmetry coefficient  \
# 205  12.19      13.20       0.8783   5.137  2.981                  3.631
# 206  11.23      12.88       0.8511   5.140  2.795                  4.325
# 207  13.20      13.66       0.8883   5.236  3.232                  8.315
# 208  11.84      13.21       0.8521   5.175  2.836                  3.598
# 209  12.30      13.34       0.8684   5.243  2.974                  5.637
#
#      groove length  category
# 205          4.870       3.0
# 206          5.003       3.0
# 207          5.056       3.0
# 208          5.044       3.0
# 209          5.063       3.0

# %%
#any null value present
df.isnull().values.any()
# Out:
# False

# %%
# to view overall null value
df.isnull()
# Out:
#       area  perimeter  compactness  length  width  asymmetry coefficient  \
# 0    False      False        False   False  False                  False
# 1    False      False        False   False  False                  False
# 2    False      False        False   False  False                  False
# 3    False      False        False   False  False                  False
# 4    False      False        False   False  False                  False
# ..     ...        ...          ...     ...    ...                    ...
# 205  False      False        False   False  False                  False
# 206  False      False        False   False  False                  False
# 207  False      False        False   False  False                  False
# 208  False      False        False   False  False                  False
# 209  False      False        False   False  False                  False
#
#      groove length  category
# 0            False     False
# 1            False     False
# ...

# %%
df['category'] = df['category'].astype(float)

# %%
df.dtypes
# Out:
# area                     float64
# perimeter                float64
# compactness              float64
# length                   float64
# width                    float64
# asymmetry coefficient    float64
# groove length            float64
# category                 float64
# dtype: object

# %%
df.dtypes
# Out:
# area                     float64
# perimeter                float64
# compactness              float64
# length                   float64
# width                    float64
# asymmetry coefficient    float64
# groove length            float64
# category                 float64
# dtype: object

# %%
# to check how many null value are present acc to col
df.isnull().sum()
# Out:
# area                     0
# perimeter                0
# compactness              0
# length                   0
# width                    0
# asymmetry coefficient    0
# groove length            0
# category                 0
# dtype: int64

# %%
# to plot the missing values
sns.heatmap(df.isnull(), yticklabels=False,cmap="viridis")
plt.show()

# %%
# number of null values in each column after treating missing value
df.isnull().sum()
# Out:
# area                     0
# perimeter                0
# compactness              0
# length                   0
# width                    0
# asymmetry coefficient    0
# groove length            0
# category                 0
# dtype: int64

# %%
df['category'].value_counts()
# Out:
# 1.0    70
# 2.0    70
# 3.0    70
# Name: category, dtype: int64

# %%
df.columns
# Out:
# Index(['area', 'perimeter', 'compactness', 'length', 'width',
#        'asymmetry coefficient', 'groove length', 'category'],
#       dtype='object')

# %% [markdown]
# # Data Visualization

# %%
#Examaning a correlation matrix of all the features 
corrmat = df.corr()
plt.subplots(figsize=(10,10))
sns.heatmap(corrmat,cmap="viridis", square=True,annot=True)
plt.show()

# %%
ax = sns.countplot(x=df['category'], hue=df['groove length'], color='blue')

# Remove the legend
ax.get_legend().remove()

plt.show()

# %%
ax = sns.countplot(x=df['category'], hue=df['length'],width=0.8)

# Remove the legend
ax.get_legend().remove()

plt.show()

# %%
ax = sns.countplot(x=df['category'], hue=df['width'],width=0.8)

# Remove the legend
ax.get_legend().remove()

plt.show()

# %%
ax = sns.countplot(x=df['category'], hue=df['asymmetry coefficient'],width=0.8)

# Remove the legend
ax.get_legend().remove()

plt.show()

# %%
ax = sns.countplot(x=df['category'], hue=df['compactness'],width=0.8)

# Remove the legend
ax.get_legend().remove()

plt.show()

# %%
column=['area','perimeter','compactness','length','width','asymmetry coefficient','groove length']
for category in column:
    plt.figure(figsize=(3,3))
    plt.hist(df[category])
    plt.title(category)
    plt.show()

# %%
category_name=['Kama', 'Rosa', 'Canadian']
plt.pie(df['category'].value_counts(),labels=category_name,autopct="%.2f%%")
plt.show()

# %%
# Default distribution according to annual salaries
fig = plt.figure(figsize = (20, 9))
sns.set_style("dark")
sns.kdeplot(df[df['category']==1]['groove length'])
sns.kdeplot(df[df['category']==2]['groove length'])
sns.kdeplot(df[df['category']==3]['groove length'])
plt.title('Category x Groove length')
plt.legend(labels=['Kama', 'Rosa','Canadian'])
plt.show()

# %%
sns.countplot(df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'area'),
#   Text(1, 0, 'perimeter'),
#   Text(2, 0, 'compactness'),
#   Text(3, 0, 'length'),
#   Text(4, 0, 'width'),
#   Text(5, 0, 'asymmetry coefficient'),
#   Text(6, 0, 'groove length'),
#   Text(7, 0, 'category')])

# %%
sns.pairplot(df, hue="category")
plt.show()

# %%
sns.kdeplot(df)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.stripplot(df)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'area'),
#   Text(1, 0, 'perimeter'),
#   Text(2, 0, 'compactness'),
#   Text(3, 0, 'length'),
#   Text(4, 0, 'width'),
#   Text(5, 0, 'asymmetry coefficient'),
#   Text(6, 0, 'groove length'),
#   Text(7, 0, 'category')])

# %%
sns.barplot(df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'area'),
#   Text(1, 0, 'perimeter'),
#   Text(2, 0, 'compactness'),
#   Text(3, 0, 'length'),
#   Text(4, 0, 'width'),
#   Text(5, 0, 'asymmetry coefficient'),
#   Text(6, 0, 'groove length'),
#   Text(7, 0, 'category')])

# %%
sns.boxplot(df)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'area'),
#   Text(1, 0, 'perimeter'),
#   Text(2, 0, 'compactness'),
#   Text(3, 0, 'length'),
#   Text(4, 0, 'width'),
#   Text(5, 0, 'asymmetry coefficient'),
#   Text(6, 0, 'groove length'),
#   Text(7, 0, 'category')])

# %% [markdown]
# # Logistics Regression

# %%
#Importing Libraries
import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

from sklearn.model_selection import RandomizedSearchCV

# %%
df.columns
# Out:
# Index(['area', 'perimeter', 'compactness', 'length', 'width',
#        'asymmetry coefficient', 'groove length', 'category'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
# Using Standard scaler technique to convert all the numerical values into same decimal format
numerical_cols=['area', 'perimeter', 'compactness', 'length', 'width',
       'asymmetry coefficient', 'groove length']
scaler=StandardScaler()
scaled_cols=pd.DataFrame(scaler.fit_transform(df[numerical_cols]),columns=scaler.get_feature_names_out(numerical_cols))

# %%
X=scaled_cols
y=df['category']

# %%
X
# Out:
#          area  perimeter  compactness    length     width  \
# 0    0.142098   0.215462     0.000061  0.304218  0.141702
# 1    0.011188   0.008224     0.428515 -0.168625  0.197432
# 2   -0.192067  -0.360201     1.442383 -0.763637  0.208048
# 3   -0.347091  -0.475333     1.039381 -0.688978  0.319508
# 4    0.445257   0.330595     1.374509  0.066666  0.805159
# ..        ...        ...          ...       ...       ...
# 205 -0.915515  -1.043321     0.309736 -1.112048 -0.736716
# 206 -1.246235  -1.288937    -0.844122 -1.105261 -1.230328
# 207 -0.567571  -0.690247     0.733948 -0.888070 -0.070604
# 208 -1.036090  -1.035645    -0.801701 -1.026077 -1.121521
# 209 -0.877620  -0.935864    -0.110235 -0.872233 -0.755292
#
#      asymmetry coefficient  groove length
# 0                -0.986152      -0.383577
# 1                -1.788166      -0.922013
# 2                -0.667479      -1.189192
# 3                -0.960818      -1.229983
# 4                -1.563495      -0.475356
# ...

# %%
y
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 205    3.0
# 206    3.0
# 207    3.0
# 208    3.0
# 209    3.0
# Name: category, Length: 210, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=5)

# %%
log = LogisticRegression()

# %%
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#train Score
Train_score = log.score(X_train,y_train)
print('Train_score: ',Train_score)
# Out:
# Train_score:  0.9464285714285714

# %%
#test Score
Test_score = log.score(X_test, y_test)
print('Test_Score: ',Test_score)
# Out:
# Test_Score:  0.9285714285714286

# %%
pred_train = log.predict(X_train)
pred_test = log.predict(X_test)

# %%
accuracy_logistics = accuracy_score(y_test,pred_test)
accuracy_logistics
# Out:
# 0.9285714285714286

# %%
print(metrics.classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.86      0.92      0.89        13
#          2.0       1.00      1.00      1.00        12
#          3.0       0.94      0.88      0.91        17
#
#     accuracy                           0.93        42
#    macro avg       0.93      0.94      0.93        42
# weighted avg       0.93      0.93      0.93        42

# %%
# Roc

# %%
from sklearn.metrics import matthews_corrcoef

mcc= matthews_corrcoef(y_test,pred_test)
print("MCC: ",mcc)
# Out:
# MCC:  0.8927068225145874

# %%
# Confusion Matrix
cm = confusion_matrix(y_test,pred_test)
print('Confusion Matrix: ',)
print(cm)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt = '.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:
# [[12  0  1]
#  [ 0 12  0]
#  [ 2  0 15]]

# %% [markdown]
# # tuning

# %%
# Grid Search CV

# %%
#grid search tuning parameters are deinfed, using gridsearchcv model is trained# Grid Search CV
param_grid = {
    'penalty':['l1', 'l2'],
    'C' : [0.1, 0.5, 1, 5, 10]
}
#l1 lasso l2 ridge to regularize the model , C common factor alpha LOS

# %%
grid = GridSearchCV(estimator = log, param_grid=param_grid, cv = 5)

# %%
grid.fit(X_train, y_train)
# Out:
# C:\Users\anike\anaconda3\anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anike\anaconda3\anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anike\anaconda3\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# best paramters and best model is chosen 
best_param = grid.best_params_
best_model = grid.best_estimator_

# %%
#Machine choses the best parameters
print('Best hyperparameters: ',best_param)
# Out:
# Best hyperparameters:  {'C': 10, 'penalty': 'l2'}

# %%
# predicted values of y are generated based on best model on the test data
gridlor_y_pred = best_model.predict(X_test)

# %%
Glor_acc=accuracy_score(y_test, gridlor_y_pred)
Glor_acc
# Out:
# 0.9523809523809523

# %%
#classification report generated on the testing values
print(metrics.classification_report(y_test, gridlor_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.92      0.92      0.92        13
#          2.0       1.00      1.00      1.00        12
#          3.0       0.94      0.94      0.94        17
#
#     accuracy                           0.95        42
#    macro avg       0.95      0.95      0.95        42
# weighted avg       0.95      0.95      0.95        42

# %%
#confusion matrix
cm = confusion_matrix(y_test,gridlor_y_pred)
print('Confusion Matrix: ',)
print(cm)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt = '.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:
# [[12  0  1]
#  [ 0 12  0]
#  [ 1  0 16]]

# %%
#randomizedsearchcv

# %%
from scipy.stats import loguniform
from sklearn.model_selection import RandomizedSearchCV
#randomized search tuning parameters are deinfed, using randomized searchcv the model is trained
logistic_random_param={'C':loguniform(1e-4,1e0),
                      'max_iter':(np.arange(100,800,10))}
grid=RandomizedSearchCV(estimator=log, param_distributions=logistic_random_param, cv=5)

# %%
grid.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(),
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000015C7C4AB850>,
#                                         'max_iter': array([100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210, 220,
#        230, 240, 250, 260, 270, 280, 290, 300, 310, 320, 330, 340, 350,
#        360, 370, 380, 390, 400, 410, 420, 430, 440, 450, 460, 470, 480,
#        490, 500, 510, 520, 530, 540, 550, 560, 570, 580, 590, 600, 610,
#        620, 630, 640, 650, 660, 670, 680, 690, 700, 710, 720, 730, 740,
#        750, 760, 770, 780, 790])})

# %%
# best paramters and best model is chosen
best_param = grid.best_params_
best_model = grid.best_estimator_

# %%
#Machine choses the best parameters 
print("Best Hyperparameters:", best_param)
# Out:
# Best Hyperparameters: {'C': 0.9754925706705061, 'max_iter': 220}

# %%
#predict y
ranlor_y_pred = best_model.predict(X_test)

# %%
Rlor_acc=accuracy_score(y_test, ranlor_y_pred)
Rlor_acc
# Out:
# 0.9285714285714286

# %%
#classification report
print(metrics.classification_report(y_test, ranlor_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.86      0.92      0.89        13
#          2.0       1.00      1.00      1.00        12
#          3.0       0.94      0.88      0.91        17
#
#     accuracy                           0.93        42
#    macro avg       0.93      0.94      0.93        42
# weighted avg       0.93      0.93      0.93        42

# %%
cm = confusion_matrix(y_test,ranlor_y_pred)
print('Confusion Matrix: ')
print(cm)
sns.heatmap(cm, annot=True, fmt = '.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:
# [[12  0  1]
#  [ 0 12  0]
#  [ 2  0 15]]

# %% [markdown]
# # SVM

# %%
#importing important libraries
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
from sklearn.metrics import roc_curve,auc

# %%
svcm= SVC()

# %%
#build the model
svcm.fit(X_train,y_train)
# Out:
# SVC()

# %%
#predicting the values of Y based on X-test
svcm_y_pred = svcm.predict(X_test)

# %%
# accuracy
accuracy_SVM=accuracy_score(y_test,svcm_y_pred)
print('Accuracy:',accuracy_SVM)
# Out:
# Accuracy: 0.9523809523809523

# %%
#classification report
print(classification_report(y_test,svcm_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.87      1.00      0.93        13
#          2.0       1.00      1.00      1.00        12
#          3.0       1.00      0.88      0.94        17
#
#     accuracy                           0.95        42
#    macro avg       0.96      0.96      0.96        42
# weighted avg       0.96      0.95      0.95        42

# %%
#confusion matrix
cm = confusion_matrix(y_test,svcm_y_pred)
print('Confusion Matrix: ')
print(cm)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:
# [[13  0  0]
#  [ 0 12  0]
#  [ 2  0 15]]

# %%
#roc curve
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier

yb= label_binarize(y, classes=[0,1,2])
nc= yb.shape[1]
classifier = OneVsRestClassifier(SVC(kernel='linear', probability=True, random_state=0))
y_score = classifier.fit(X_train, y_train).decision_function(X_test)
fpr=dict()
tpr=dict()
roc_auc = dict()
for i in range(nc):
    fpr[i], tpr[i], _ = roc_curve(y_test ==i, y_score[:,i])
    roc_auc[i] = auc(fpr[i], tpr[i])
plt.figure()
color = ['blue','red','green']
for i, color in zip(range(nc),color):
    plt.plot (fpr[i], tpr[i], color=color, lw=2,
             label='ROC(area= {: .2f}) for class{}'.format(roc_auc[i],df['category'][i]))
plt.plot([0,1], [0,1], 'k--', lw=2)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC')
plt.show()
# Out:
# C:\Users\anike\anaconda3\anaconda\Lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %% [markdown]
# # tuning

# %%
#importing important libraries
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
# grid search

# %%
#providing values for different parameters used in the gridsearchcv such as common factor 'C', gamma (regularization strength),kernel type.
param_grid = {
    'C': [0.1, 1, 10],            # Regularization parameter
    'gamma': [1,0.1,0.01,0.001],
    'kernel': ['linear', 'rbf','poly','sigmoid'],  # Kernel type
      
}

# %%
grid=GridSearchCV(svcm,param_grid,cv=5,verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.971 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.912 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.882 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.879 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.970 total time=   0.0s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.824 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.970 total time=   0.0s
# [CV 1/5] END .......C=0.1, gamma=1, kernel=poly;, score=1.000 total time=   0.0s
# ...

# %%
best_parameter = grid.best_params_
best_model = grid.best_estimator_
print('hyperparameters: ',best_parameter)
# Out:
# hyperparameters:  {'C': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}

# %%
#predicting y
svm_grid_y_pred = best_model.predict(X_test)

# %%
#accuracy
Gsvm_acc=accuracy_score(y_test,svm_grid_y_pred)
print("Accuracy:",Gsvm_acc)
# Out:
# Accuracy: 0.9285714285714286

# %%
#classification report
print(classification_report(y_test,svm_grid_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.86      0.92      0.89        13
#          2.0       1.00      1.00      1.00        12
#          3.0       0.94      0.88      0.91        17
#
#     accuracy                           0.93        42
#    macro avg       0.93      0.94      0.93        42
# weighted avg       0.93      0.93      0.93        42

# %%
#confusion Matrix
cm = confusion_matrix(y_test,svm_grid_y_pred)
print('Confusion Matrix: ')
print(cm)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:
# [[12  0  1]
#  [ 0 12  0]
#  [ 2  0 15]]

# %%
# randomizedsearchcv

# %%
param_grid = {
    'C': [0.1, 1, 10],            # Regularization parameter
    'kernel': ['linear', 'rbf','poly','sigmoid'],  # Kernel type
      
}
random=RandomizedSearchCV(svcm, param_grid, cv=5)

# %%
random.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [0.1, 1, 10],
#                                         'kernel': ['linear', 'rbf', 'poly',
#                                                    'sigmoid']})

# %%
best_parameters = random.best_params_
best_model = random.best_estimator_
print('Hyperparameters:',best_parameters)
# Out:
# Hyperparameters: {'kernel': 'linear', 'C': 10}

# %%
#predict of y
svmran_y_pred = best_model.predict(X_test)

# %%
#accuracy
Rsvm_acc=accuracy_score(y_test,svmran_y_pred)
print("Accuracy:",Rsvm_acc)
# Out:
# Accuracy: 0.9523809523809523

# %%
#classification report
print(classification_report(y_test,svmran_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.92      0.92      0.92        13
#          2.0       1.00      1.00      1.00        12
#          3.0       0.94      0.94      0.94        17
#
#     accuracy                           0.95        42
#    macro avg       0.95      0.95      0.95        42
# weighted avg       0.95      0.95      0.95        42

# %%
#confusion matrix
cm = confusion_matrix(y_test,svmran_y_pred)
print('Confusion Matrix: ')
print(cm)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:
# [[12  0  1]
#  [ 0 12  0]
#  [ 1  0 16]]

# %% [markdown]
# # kNN

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create the k-NN classifier with a specified number of neighbors (k)
k = 5  # You can adjust the value of k
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(X_test,y_test)
# Out:
# 0.9523809523809523

# %%
knn_y_pred = knn.predict(X_test)

# %%
accuracy_kNN = accuracy_score(y_test, knn_y_pred)
print("Accuracy:", accuracy_kNN)
# Out:
# Accuracy: 0.9523809523809523

# %%
 print(classification_report(y_test, knn_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.87      1.00      0.93        13
#          2.0       1.00      1.00      1.00        12
#          3.0       1.00      0.88      0.94        17
#
#     accuracy                           0.95        42
#    macro avg       0.96      0.96      0.96        42
# weighted avg       0.96      0.95      0.95        42

# %%
cm=confusion_matrix(y_test,knn_y_pred)
print(cm)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# [[13  0  0]
#  [ 0 12  0]
#  [ 2  0 15]]

# %%
yb=label_binarize(y, classes=[0,1,2])
nc = yb.shape[1] 
classifier = OneVsRestClassifier(knn)
y_score=classifier.fit(X_train,y_train).predict(X_test)
fpr=dict()
tpr=dict()
roc_auc=dict()

for i in range (nc):
    fpr[i],tpr[i],_=roc_curve(y_test == i, y_score)
    roc_auc[i]=auc(fpr[i],tpr[i])
plt.figure()
color=['blue','red','green']
for i, color in zip(range(nc),color):
    plt.plot(fpr[i],tpr[i],color=color, lw=2, label='ROC (area={:.2f}) for class {}'.format(roc_auc[i],df['category'][i]))
plt.plot([0,1],[0,1],'k--',lw=2)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC')
plt.show()
# Out:
# C:\Users\anike\anaconda3\anaconda\Lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
# Tuning kNN

# %%
#GridSearchCV

# %%
param_grid = {
    'n_neighbors': [3, 5, 7, 9],  # Test different values of k
    'weights': ['uniform', 'distance'],  # Weighting type
    'p': [1, 2],  # Distance metric (1 for Manhattan, 2 for Euclidean)
}

# %%
knn = KNeighborsClassifier()
grid_search = GridSearchCV(knn, param_grid, cv=5,scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
best_param = grid_search.best_params_
best_knn = KNeighborsClassifier(n_neighbors = best_param['n_neighbors'], weights = best_param['weights'],p=best_param['p'])
best_knn.fit(X_train, y_train)
knn_grid_y_pred = best_knn.predict(X_test)

# %%
print("Best Hyperparameter : ", best_param)
# Out:
# Best Hyperparameter :  {'n_neighbors': 7, 'p': 1, 'weights': 'distance'}

# %%
Gknn_acc = accuracy_score(y_test, knn_grid_y_pred)
Gknn_acc
# Out:
# 0.9523809523809523

# %%
print (classification_report(y_test,knn_grid_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.87      1.00      0.93        13
#          2.0       1.00      1.00      1.00        12
#          3.0       1.00      0.88      0.94        17
#
#     accuracy                           0.95        42
#    macro avg       0.96      0.96      0.96        42
# weighted avg       0.96      0.95      0.95        42

# %%
cm=confusion_matrix(y_test,knn_grid_y_pred)
print(cm)
sns.heatmap(cm, annot=True, fmt='.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# [[13  0  0]
#  [ 0 12  0]
#  [ 2  0 15]]

# %%
# Euclidean

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors=5, metric='euclidean')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
y_pred = knn_classifier.predict(X_test)  # X_test: test features

# %%
accuracy = accuracy_score(y_test, y_pred)  # For classification
print('accuracy:',accuracy)
# Out:
# accuracy: 0.9523809523809523

# %%
print(classification_report(y_test, y_pred))  # For classification
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.87      1.00      0.93        13
#          2.0       1.00      1.00      1.00        12
#          3.0       1.00      0.88      0.94        17
#
#     accuracy                           0.95        42
#    macro avg       0.96      0.96      0.96        42
# weighted avg       0.96      0.95      0.95        42

# %%
cm=confusion_matrix(y_test,y_pred)
print(cm)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# [[13  0  0]
#  [ 0 12  0]
#  [ 2  0 15]]

# %%
#Manhatan

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=5, metric='manhattan')

# %%
knn_classifier.fit(X_train, y_train)  # X_train: training features, y_train: training labels
# Out:
# KNeighborsClassifier(metric='manhattan')

# %%
y_pred = knn_classifier.predict(X_test)  # X_test: test features

# %%
accuracy = accuracy_score(y_test, y_pred)  # For classification
print('accuracy:',accuracy)
# Out:
# accuracy: 0.9761904761904762

# %%
print(classification_report(y_test, y_pred))  # For classification
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.93      1.00      0.96        13
#          2.0       1.00      1.00      1.00        12
#          3.0       1.00      0.94      0.97        17
#
#     accuracy                           0.98        42
#    macro avg       0.98      0.98      0.98        42
# weighted avg       0.98      0.98      0.98        42

# %%
#confusion Matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# [[13  0  0]
#  [ 0 12  0]
#  [ 1  0 16]]

# %%
# Minkowsky

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#prediction of y
y_pred = knn_classifier.predict(X_test)  # X_test: test fea

# %%
#accuracy
accuracy = accuracy_score(y_test, y_pred)  # For classification
print('accuracy:',accuracy)
# Out:
# accuracy: 0.9523809523809523

# %%
#classificarion report
print(classification_report(y_test, y_pred))  # For classification
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.87      1.00      0.93        13
#          2.0       1.00      1.00      1.00        12
#          3.0       1.00      0.88      0.94        17
#
#     accuracy                           0.95        42
#    macro avg       0.96      0.96      0.96        42
# weighted avg       0.96      0.95      0.95        42

# %%
#confusion Matrix 
cm=confusion_matrix(y_test,y_pred)
print(cm)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='.3g')
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# [[13  0  0]
#  [ 0 12  0]
#  [ 2  0 15]]

# %%
# Create a dictionary to store accuracy values for each model
data= {
    "Model": ["Logistic Regression", "SVM", "k-NN"],
    "Accuracy": [ accuracy_logistics,accuracy_SVM, accuracy_kNN],
    "GridSearchCV":[Glor_acc,Gsvm_acc,Gknn_acc],
   
    
}


accuracy_data = pd.DataFrame(data)
accuracy_data
# Out:
#                  Model  Accuracy  GridSearchCV
# 0  Logistic Regression  0.928571      0.952381
# 1                  SVM  0.952381      0.928571
# 2                 k-NN  0.952381      0.952381
